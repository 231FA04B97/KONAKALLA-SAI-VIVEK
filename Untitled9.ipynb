# %% [markdown]
# <a href="https://colab.research.google.com/github/231FA04B97/KONAKALLA-SAI-VIVEK/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
# !pip install pytesseract pillow

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/download (1).png"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(366.5), np.float64(136.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print(text)
# Out:
# “he Standard Service te @ qualily handusrling fost sruist,
# hich dese nd inchute the extra character variations,
# Hoveuar, & dill produces a geod quality handustiing fot
# frou natural handurting “he Standart Seruice te suctalle
# fer bah cursive (etd up) and prsted, handaceing

# %%
ipp = "/content/download (89).jpg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(167.5), np.float64(-0.5))

# %%
img = Image.open(ipp)
text = pytesseract.image_to_string(img)
print(text)

# %%
aa= gTTS(text)

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter a text :")
translated = t.translate(text,src='en',dest='te')
print("Translated.text :",translated.text)
# Out:
# Enter a text :SAI VIVEK KONAKALLA
# Translated.text: సాయి వివేక్ కోనకల్లా
